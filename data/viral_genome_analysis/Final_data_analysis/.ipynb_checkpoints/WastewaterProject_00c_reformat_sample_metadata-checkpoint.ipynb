# %%
import os
import sys
import glob
import scipy
import skbio
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
from collections import defaultdict
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %matplotlib inline
sns.set_style('whitegrid')
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['pdf.fonttype'] = 42

from IPython.display import display, HTML
import tRep

import warnings
warnings.filterwarnings("ignore")

pd.options.display.max_columns = 100
pd.options.display.max_colwidth = 500
pd.options.display.max_rows = 100

# %%
Mdb = pd.read_csv('/groups/banfield/projects/human/data3/clou/wastewater/Datasheets/metadata/sample_metadata.tsv',sep='\t')
Mdb = Mdb.rename(columns=lambda x: x.strip())
Mdb.to_csv('/groups/banfield/projects/human/data3/clou/wastewater/Datasheets/metadata/sample_metadata_v1_original.csv',index=False)

# %%
Mdb2 = Mdb.copy()
Mdb2['sample'] = [x.strip() for x in Mdb2['sample']]
Mdb2['core'] = [x.strip() for x in Mdb2['core']]
Mdb2.at[11,'sample'] = '6_09_S1'
Mdb2
# Out:
#           sample      core        location   method      date  mean_ct  \
# 0      5_13_A_S1      MIGS        Oakland   amicon   05/13/20    30.70
# 1      5_13_C_S2      MIGS        Oakland   amicon   05/13/20    30.70
# 2      5_19_F_S3      MIGS        Oakland   amicon   05/19/20    29.50
# 3      5_19_A_S4      MIGS        Oakland   amicon   05/19/20    29.50
# 4         5_28_I      MIGS        Oakland   amicon   05/28/20    31.37
# 5         5_28_E      MIGS       Berkeley   amicon   05/28/20    33.80
# 6         5_28_A      MIGS  BerkeleyHills   amicon   05/28/20    35.47
# 7        6_02_Nc      MIGS       Berkeley   amicon   06/02/20    33.37
# 8        6_02_Sc      MIGS        Oakland   amicon   06/02/20    30.37
# 9        6_02_Ac      MIGS  BerkeleyHills   amicon   06/02/20    36.23
# 10       6_09_N1      MIGS       Berkeley   amicon   06/09/20    36.80
# 11       6_09_S1      MIGS        Oakland   amicon   06/09/20    32.19
# 12  S_3_6_30_MOS      MIGS        Oakland      MOS   06/30/20    32.56
# 13  S_3_6_30_COL      MIGS        Oakland      COL   06/30/20    29.91
# 14  SQ_3_7_1_MOS      MIGS     SanQuentin      MOS   07/01/20    27.16
# 15  MR_1_7_1_MOS      MIGS          Marin      MOS   07/01/20    29.79
# 16        p630-N  ILLUMINA       Berkeley      COL   06/30/20    34.80
# 17       p630-S1  ILLUMINA        Oakland      COL   06/30/20    31.30
# 18       p630-S2  ILLUMINA        Oakland      COL   06/30/20    30.03
# 19      p630-SF1  ILLUMINA             SF      MOS   06/30/20    34.97
# 20          pMR2  ILLUMINA          Marin      MOS   07/01/20    31.79
# 21          pMR3  ILLUMINA          Marin      MOS   07/01/20    31.01
# 22        pS68-1  ILLUMINA        Oakland      COL   06/30/20    32.52
# 23          pSQ1  ILLUMINA     SanQuentin      MOS   07/01/20    26.91
# 24          pSQ2  ILLUMINA     SanQuentin      MOS   07/01/20    27.02
# 25         630-N  ILLUMINA       Berkeley      COL   06/30/20    34.80
# 26        630-S1  ILLUMINA        Oakland      COL   06/30/20    31.30
# 27        630-S2  ILLUMINA        Oakland      COL   06/30/20    30.03
# 28       630-SF1  ILLUMINA             SF      MOS   06/30/20    34.97
# 29           MR2  ILLUMINA          Marin      MOS   07/01/20    31.79
# 30           MR3  ILLUMINA          Marin      MOS   07/01/20    31.01
# 31         S68-1  ILLUMINA        Oakland      COL   06/30/20    32.52
# 32           SQ1  ILLUMINA     SanQuentin      MOS   07/01/20    26.91
# 33           SQ2  ILLUMINA     SanQuentin      MOS   07/01/20    27.02
#
#     ct_from_replicate  sequencing
# 0                   1    enriched
# 1                   0    enriched
# 2                   0    enriched
# 3                   1    enriched
# 4                   0    enriched
# 5                   0    enriched
# 6                   0    enriched
# 7                   0    enriched
# 8                   0    enriched
# 9                   0    enriched
# 10                  0    enriched
# 11                  0    enriched
# 12                  0    enriched
# 13                  0    enriched
# 14                  0    enriched
# 15                  0    enriched
# 16                  0    enriched
# 17                  0    enriched
# 18                  0    enriched
# 19                  0    enriched
# 20                  0    enriched
# 21                  0    enriched
# 22                  0    enriched
# 23                  0    enriched
# 24                  0    enriched
# 25                  0  unenriched
# 26                  0  unenriched
# 27                  0  unenriched
# 28                  0  unenriched
# 29                  0  unenriched
# 30                  0  unenriched
# 31                  0  unenriched
# 32                  0  unenriched
# 33                  0  unenriched

# %%
# check if sample naming is all the same

Rdb = pd.read_csv('/groups/banfield/projects/human/data3/clou/wastewater/Datasheets/waster_water_readDepths_formatted.csv')
Rdb
# Out:
#               sample  read_bases     reads  read_length Illumina_enrichment
# 0          5_13_A_S1     6107540     82174    74.324482          unenriched
# 1          5_13_C_S2     1796238     24144    74.396869          unenriched
# 2          5_19_A_S4    25431914    343252    74.091088          unenriched
# 3          5_19_F_S3    24851304    334748    74.238842          unenriched
# 4         5_28_A_S28    71023874    978422    72.590226          unenriched
# 5         5_28_E_S26    72838764   1009198    72.174899          unenriched
# 6         5_28_I_S25    89771642   1248062    71.928832          unenriched
# 7              630-N  4177966696  54973246    76.000000          unenriched
# 8             630-S1  2563889792  33735392    76.000000          unenriched
# 9             630-S2  4420453816  58163866    76.000000          unenriched
# 10           630-SF1  5264810168  69273818    76.000000          unenriched
# 11       6_02_Ac_S31   135654468   1880856    72.123793          unenriched
# 12       6_02_Nc_S27   149433644   2067544    72.275920          unenriched
# 13       6_02_Sc_S29   137437792   1903536    72.201310          unenriched
# 14       6_09_N1_S30    67305300    939218    71.660999          unenriched
# 15       6_09_S1_S33    67911660    953280    71.239992          unenriched
# 16               MR2  2772684744  36482694    76.000000          unenriched
# 17               MR3  3226234200  42450450    76.000000          unenriched
# 18  MR_1_7_1_MOS_S16   430014196   5782718    74.361952          unenriched
# 19             S68-1  4424180704  58212904    76.000000          unenriched
# 20               SQ1  5214174560  68607560    76.000000          unenriched
# 21               SQ2  5188093336  68264386    76.000000          unenriched
# 22  SQ_3_7_1_MOS_S15   156949712   2109792    74.391083          unenriched
# 23  S_3_6_30_COL_S14   358105668   4810964    74.435325          unenriched
# 24  S_3_6_30_MOS_S13   141314258   1906076    74.138837          unenriched
# 25            p630-N  1316671172  17550012    75.023947            enriched
# 26           p630-S1   215779624   2945434    73.259025            enriched
# 27           p630-S2   910231584  12534044    72.620743            enriched
# 28          p630-SF1   890426416  12335804    72.182277            enriched
# 29              pMR2   147980404   2046222    72.318841            enriched
# 30              pMR3  1502600204  20761090    72.375786            enriched
# 31            pS68-1  1273909514  17384174    73.279841            enriched
# 32              pSQ1   152090012   2115286    71.900448            enriched
# 33              pSQ2  1010081054  14005704    72.119263            enriched

# %%
inconsistent_sample_name = list(set(Mdb2['sample'])-set(Rdb['sample']))
print(len(inconsistent_sample_name))
inconsistent_sample_name
# Out:
# 12
# ['MR_1_7_1_MOS',
#  'SQ_3_7_1_MOS',
#  '6_02_Sc',
#  '6_02_Nc',
#  'S_3_6_30_MOS',
#  '6_09_N1',
#  '6_09_S1',
#  '5_28_E',
#  'S_3_6_30_COL',
#  '5_28_A',
#  '6_02_Ac',
#  '5_28_I']

# %%
Mdb3 = Mdb2.copy()

for i,row in Mdb3.iterrows():
    if row['sample'] in inconsistent_sample_name:
        for i2,row2 in Rdb.iterrows():
            if row['sample'] in row2['sample']:
                Mdb3.at[i,'sample'] = row2['sample']
print(set(Mdb3['sample'])-set(Rdb['sample']))
print(set(Rdb['sample'])-set(Mdb3['sample']))
Mdb3
# Out:
# set()
# set()
#               sample      core        location   method      date  mean_ct  \
# 0          5_13_A_S1      MIGS        Oakland   amicon   05/13/20    30.70
# 1          5_13_C_S2      MIGS        Oakland   amicon   05/13/20    30.70
# 2          5_19_F_S3      MIGS        Oakland   amicon   05/19/20    29.50
# 3          5_19_A_S4      MIGS        Oakland   amicon   05/19/20    29.50
# 4         5_28_I_S25      MIGS        Oakland   amicon   05/28/20    31.37
# 5         5_28_E_S26      MIGS       Berkeley   amicon   05/28/20    33.80
# 6         5_28_A_S28      MIGS  BerkeleyHills   amicon   05/28/20    35.47
# 7        6_02_Nc_S27      MIGS       Berkeley   amicon   06/02/20    33.37
# 8        6_02_Sc_S29      MIGS        Oakland   amicon   06/02/20    30.37
# 9        6_02_Ac_S31      MIGS  BerkeleyHills   amicon   06/02/20    36.23
# 10       6_09_N1_S30      MIGS       Berkeley   amicon   06/09/20    36.80
# 11       6_09_S1_S33      MIGS        Oakland   amicon   06/09/20    32.19
# 12  S_3_6_30_MOS_S13      MIGS        Oakland      MOS   06/30/20    32.56
# 13  S_3_6_30_COL_S14      MIGS        Oakland      COL   06/30/20    29.91
# 14  SQ_3_7_1_MOS_S15      MIGS     SanQuentin      MOS   07/01/20    27.16
# 15  MR_1_7_1_MOS_S16      MIGS          Marin      MOS   07/01/20    29.79
# 16            p630-N  ILLUMINA       Berkeley      COL   06/30/20    34.80
# 17           p630-S1  ILLUMINA        Oakland      COL   06/30/20    31.30
# 18           p630-S2  ILLUMINA        Oakland      COL   06/30/20    30.03
# 19          p630-SF1  ILLUMINA             SF      MOS   06/30/20    34.97
# 20              pMR2  ILLUMINA          Marin      MOS   07/01/20    31.79
# 21              pMR3  ILLUMINA          Marin      MOS   07/01/20    31.01
# 22            pS68-1  ILLUMINA        Oakland      COL   06/30/20    32.52
# 23              pSQ1  ILLUMINA     SanQuentin      MOS   07/01/20    26.91
# 24              pSQ2  ILLUMINA     SanQuentin      MOS   07/01/20    27.02
# 25             630-N  ILLUMINA       Berkeley      COL   06/30/20    34.80
# 26            630-S1  ILLUMINA        Oakland      COL   06/30/20    31.30
# 27            630-S2  ILLUMINA        Oakland      COL   06/30/20    30.03
# 28           630-SF1  ILLUMINA             SF      MOS   06/30/20    34.97
# 29               MR2  ILLUMINA          Marin      MOS   07/01/20    31.79
# 30               MR3  ILLUMINA          Marin      MOS   07/01/20    31.01
# 31             S68-1  ILLUMINA        Oakland      COL   06/30/20    32.52
# 32               SQ1  ILLUMINA     SanQuentin      MOS   07/01/20    26.91
# 33               SQ2  ILLUMINA     SanQuentin      MOS   07/01/20    27.02
#
#     ct_from_replicate  sequencing
# 0                   1    enriched
# 1                   0    enriched
# 2                   0    enriched
# 3                   1    enriched
# 4                   0    enriched
# 5                   0    enriched
# 6                   0    enriched
# 7                   0    enriched
# 8                   0    enriched
# 9                   0    enriched
# 10                  0    enriched
# 11                  0    enriched
# 12                  0    enriched
# 13                  0    enriched
# 14                  0    enriched
# 15                  0    enriched
# 16                  0    enriched
# 17                  0    enriched
# 18                  0    enriched
# 19                  0    enriched
# 20                  0    enriched
# 21                  0    enriched
# 22                  0    enriched
# 23                  0    enriched
# 24                  0    enriched
# 25                  0  unenriched
# 26                  0  unenriched
# 27                  0  unenriched
# 28                  0  unenriched
# 29                  0  unenriched
# 30                  0  unenriched
# 31                  0  unenriched
# 32                  0  unenriched
# 33                  0  unenriched

# %%
Mdb3['sample_complete_description'] = ["_".join([x,y]) for x,y in zip(Mdb3['sample'],Mdb3['core'])]
Mdb3
# Out:
#               sample      core        location   method      date  mean_ct  \
# 0          5_13_A_S1      MIGS        Oakland   amicon   05/13/20    30.70
# 1          5_13_C_S2      MIGS        Oakland   amicon   05/13/20    30.70
# 2          5_19_F_S3      MIGS        Oakland   amicon   05/19/20    29.50
# 3          5_19_A_S4      MIGS        Oakland   amicon   05/19/20    29.50
# 4         5_28_I_S25      MIGS        Oakland   amicon   05/28/20    31.37
# 5         5_28_E_S26      MIGS       Berkeley   amicon   05/28/20    33.80
# 6         5_28_A_S28      MIGS  BerkeleyHills   amicon   05/28/20    35.47
# 7        6_02_Nc_S27      MIGS       Berkeley   amicon   06/02/20    33.37
# 8        6_02_Sc_S29      MIGS        Oakland   amicon   06/02/20    30.37
# 9        6_02_Ac_S31      MIGS  BerkeleyHills   amicon   06/02/20    36.23
# 10       6_09_N1_S30      MIGS       Berkeley   amicon   06/09/20    36.80
# 11       6_09_S1_S33      MIGS        Oakland   amicon   06/09/20    32.19
# 12  S_3_6_30_MOS_S13      MIGS        Oakland      MOS   06/30/20    32.56
# 13  S_3_6_30_COL_S14      MIGS        Oakland      COL   06/30/20    29.91
# 14  SQ_3_7_1_MOS_S15      MIGS     SanQuentin      MOS   07/01/20    27.16
# 15  MR_1_7_1_MOS_S16      MIGS          Marin      MOS   07/01/20    29.79
# 16            p630-N  ILLUMINA       Berkeley      COL   06/30/20    34.80
# 17           p630-S1  ILLUMINA        Oakland      COL   06/30/20    31.30
# 18           p630-S2  ILLUMINA        Oakland      COL   06/30/20    30.03
# 19          p630-SF1  ILLUMINA             SF      MOS   06/30/20    34.97
# 20              pMR2  ILLUMINA          Marin      MOS   07/01/20    31.79
# 21              pMR3  ILLUMINA          Marin      MOS   07/01/20    31.01
# 22            pS68-1  ILLUMINA        Oakland      COL   06/30/20    32.52
# 23              pSQ1  ILLUMINA     SanQuentin      MOS   07/01/20    26.91
# 24              pSQ2  ILLUMINA     SanQuentin      MOS   07/01/20    27.02
# 25             630-N  ILLUMINA       Berkeley      COL   06/30/20    34.80
# 26            630-S1  ILLUMINA        Oakland      COL   06/30/20    31.30
# 27            630-S2  ILLUMINA        Oakland      COL   06/30/20    30.03
# 28           630-SF1  ILLUMINA             SF      MOS   06/30/20    34.97
# 29               MR2  ILLUMINA          Marin      MOS   07/01/20    31.79
# 30               MR3  ILLUMINA          Marin      MOS   07/01/20    31.01
# 31             S68-1  ILLUMINA        Oakland      COL   06/30/20    32.52
# 32               SQ1  ILLUMINA     SanQuentin      MOS   07/01/20    26.91
# 33               SQ2  ILLUMINA     SanQuentin      MOS   07/01/20    27.02
#
#     ct_from_replicate  sequencing sample_complete_description
# 0                   1    enriched              5_13_A_S1_MIGS
# 1                   0    enriched              5_13_C_S2_MIGS
# 2                   0    enriched              5_19_F_S3_MIGS
# 3                   1    enriched              5_19_A_S4_MIGS
# 4                   0    enriched             5_28_I_S25_MIGS
# 5                   0    enriched             5_28_E_S26_MIGS
# 6                   0    enriched             5_28_A_S28_MIGS
# 7                   0    enriched            6_02_Nc_S27_MIGS
# 8                   0    enriched            6_02_Sc_S29_MIGS
# 9                   0    enriched            6_02_Ac_S31_MIGS
# 10                  0    enriched            6_09_N1_S30_MIGS
# 11                  0    enriched            6_09_S1_S33_MIGS
# 12                  0    enriched       S_3_6_30_MOS_S13_MIGS
# 13                  0    enriched       S_3_6_30_COL_S14_MIGS
# 14                  0    enriched       SQ_3_7_1_MOS_S15_MIGS
# 15                  0    enriched       MR_1_7_1_MOS_S16_MIGS
# 16                  0    enriched             p630-N_ILLUMINA
# 17                  0    enriched            p630-S1_ILLUMINA
# 18                  0    enriched            p630-S2_ILLUMINA
# 19                  0    enriched           p630-SF1_ILLUMINA
# 20                  0    enriched               pMR2_ILLUMINA
# 21                  0    enriched               pMR3_ILLUMINA
# 22                  0    enriched             pS68-1_ILLUMINA
# 23                  0    enriched               pSQ1_ILLUMINA
# 24                  0    enriched               pSQ2_ILLUMINA
# 25                  0  unenriched              630-N_ILLUMINA
# 26                  0  unenriched             630-S1_ILLUMINA
# 27                  0  unenriched             630-S2_ILLUMINA
# 28                  0  unenriched            630-SF1_ILLUMINA
# 29                  0  unenriched                MR2_ILLUMINA
# 30                  0  unenriched                MR3_ILLUMINA
# 31                  0  unenriched              S68-1_ILLUMINA
# 32                  0  unenriched                SQ1_ILLUMINA
# 33                  0  unenriched                SQ2_ILLUMINA

# %%
Mdb3.to_csv('/groups/banfield/projects/human/data3/clou/wastewater/Datasheets/metadata/sample_metadata_v2_sample_name_adjusted.csv',index=False)
